# %%
import requests
import json
from bs4 import BeautifulSoup
import os
import pandas
import urllib3
import random

# %%
#url="https://api.proxycrawl.com/?token=gV2i7Mvqy7kD4_tYQFERFg&url=https%3A%2F%2Fwww.amazon.com"

#url="https://api.proxycrawl.com/?token=gV2i7Mvqy7kD4_tYQFERFg&url=http://www.masterresellrights.com/products/rights/mrr/1"
url="http://www.masterresellrights.com/products/cat/ebooks/2"

# %%
user_agent_list = [
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
]

for i in range(1,4):
    #Pick a random user agent
    user_agent = random.choice(user_agent_list)
    #Set the headers 
    headers = {'User-Agent': user_agent}
    #Make the request
    res = requests.get(url,headers=headers)

    
print(res.status_code)
# Out:
# 200

# %%
soup=BeautifulSoup(res.content, "html.parser")

# %%
#print(soup.prettify())

# %%
# all=soup.find("section", {"class", "block_main_content left"}).div
# print(len(all))
# Out:
# 5

# %%
allTables= soup.find_all("table")
len(allTables)
# Out:
# 11

# %%
#allTr=allTables[0].find_all("tr")

# %%
#productUrl= allTr[0].a.get('href')

# %%
#productTilte= allTr[0].a.text

# %%
#imgUrl= allTr[2].img.get('src')

# %%
#getOverview= allTr[2].find_all('p')

# %%
#overview= getOverview[3].text

# %%
for i in range (0,10):
    urlInitials=("http://www.masterresellrights.com")
    allTr=allTables[i].find_all("tr")
    #title
    print(allTr[0].a.text)
    #overview
    getOverview= allTr[2].find_all('p')
    overview= getOverview[3].text
    print(overview)
    overview2= getOverview[4].text
    print(overview2)
    #productUrl
    productUrl= allTr[0].a.get('href')
    print(urlInitials+productUrl)
    #imgUrl
    imgUrl= allTr[2].img.get('src')
    print(urlInitials+imgUrl)
    
    print()
# Out:
# Age Slower
# Anti-Aging Tips to Protect Your Brain, Your Looks and Your Health!
#  Login to Download  Sign Up Now
# http://www.masterresellrights.com/products/master-resale-rights/age-slower.html
# http://www.masterresellrights.com/pub/images/products/ageslower_mrr.png
#
# Beginners Guide To Meditation
# The Beginners Guide To Meditation Helps To Show You How To Clear Your Mind And Improve Your Life!
#  Login to Download  Sign Up Now
# http://www.masterresellrights.com/products/master-resale-rights/beginners-guide-to-meditation.html
# http://www.masterresellrights.com/pub/images/products/beginguidemdttn820_mrr.png
#
# The Power Of Self-Discipline
# Discover the new psychology of success!
#  Login to Download  Sign Up Now
# http://www.masterresellrights.com/products/master-resale-rights/the-power-of-self-discipline.html
# http://www.masterresellrights.com/pub/images/products/powerselfdiscipline820_mrr.png
#
# Passive WooCommerce Profits
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import urllib3
import random

l=[]
base_url="http://www.masterresellrights.com/products/rights/mrr/"
for page in range(1,438):
    
#     import requests
#     from bs4 import BeautifulSoup
#     import urllib3
#     import random
    user_agent_list = [
        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    ]
    user_agent = random.choice(user_agent_list)
    headers = {'User-Agent': user_agent}
    
    #check if the fake browsers and urls are working fine
    print(base_url+str(page))
    #i=int(page)
    #print("Request #%d\nUser-Agent Sent:%s\n\nHeaders Recevied by HTTPBin:"%(i,user_agent))
    site=requests.get(base_url+str(page),headers=headers)
    print(site.status_code)
    
    
    soup=BeautifulSoup(site.content, "html.parser")
    allTables= soup.find_all("table")
    urlInitials=("http://www.masterresellrights.com")
    
    for i in range (0,10):
        d={}
        
        allTr=allTables[i].find_all("tr")
        #title
        try: d["Product Title"]=allTr[0].a.text
        except: d["Product Title"]=None
        #overview
        getOverview= allTr[2].find_all('p')
        try: d["Overview"]=getOverview[3].text
        except: d["Overview"]=None
            
        #overview 2nd
        try: d["Overview2"]=getOverview[4].text
        except: d["Overview2"]=None
        #productUrl
        productUrl= allTr[0].a.get('href')
        try: d["Product Url"]=urlInitials+productUrl
        except: d["Product Url"]=None
        #imgUrl
        imgUrl= allTr[2].img.get('src')
        try: d["Img Url"]=urlInitials+imgUrl
        except:  d["Img Url"]=None
        l.append(d)
# Out:
# http://www.masterresellrights.com/products/rights/mrr/1
# 200
# http://www.masterresellrights.com/products/rights/mrr/2
# 200
# http://www.masterresellrights.com/products/rights/mrr/3
# 200
# http://www.masterresellrights.com/products/rights/mrr/4
# 200
# http://www.masterresellrights.com/products/rights/mrr/5
# 200
# http://www.masterresellrights.com/products/rights/mrr/6
# 200
# http://www.masterresellrights.com/products/rights/mrr/7
# 200
# http://www.masterresellrights.com/products/rights/mrr/8
# 200
# http://www.masterresellrights.com/products/rights/mrr/9
# 200
# http://www.masterresellrights.com/products/rights/mrr/10
# 200
# http://www.masterresellrights.com/products/rights/mrr/11
# 200
# http://www.masterresellrights.com/products/rights/mrr/12
# 200
# http://www.masterresellrights.com/products/rights/mrr/13
# 200
# http://www.masterresellrights.com/products/rights/mrr/14
# 200
# http://www.masterresellrights.com/products/rights/mrr/15
# 200
# ...

# %%
len(l)
# Out:
# 4370

# %%
import pandas
df1=pandas.DataFrame(l)

# %%
df1.shape
# Out:
# (4370, 5)

# %%
# #df2 will delete first column from df1
# df2=df1.drop('Unnamed: 0', axis=1)
# df2.shape

# %%
df2_nodublicates=df1.drop_duplicates()
df2_nodublicates.shape
# Out:
# (4369, 5)

# %%
df3=df2_nodublicates.to_csv("dublicates/complete_masterresellrights_1to437_nodublicates.csv")
